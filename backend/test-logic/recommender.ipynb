# %% [markdown]
# # Credit Card Recommender
#
# This notebook will demo the credit card recommendation workflow utilizing GPT.

# %% [markdown]
# ## Preprocessing
# 1. Read in transaction history (CSV) -> convert to JSON string
# 2. Read credit card data as JSON

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from pprint import pprint
import json

from openai import OpenAI
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

from mcc_map import convert_mcc_to_category

# %%
# Import transaction data
tx_df = pd.read_csv('dummy-data/tx-data.csv')
convert_mcc_to_category(tx_df)
tx_df.head()
# Out:
#    User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0     0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1     0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2     0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3     0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4     0     0  2002      9    3  06:23  $104.71  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip      MCC  \
# 0  3527213246127876953       La Verne             CA  91750.0  grocery
# 1  -727612092139916043  Monterey Park             CA  91754.0  grocery
# 2  -727612092139916043  Monterey Park             CA  91754.0  grocery
# 3  3414527459579106770  Monterey Park             CA  91754.0   retail
# 4  5817218446178736267       La Verne             CA  91750.0   retail
#
#   Errors? Is Fraud?
# 0     NaN        No
# 1     NaN        No
# 2     NaN        No
# 3     NaN        No
# 4     NaN        No

# %%
# Group the transactions by category
tx_df["Amount"] = tx_df["Amount"].replace("[\$,]", "", regex=True).astype(float)

tx_grouped = tx_df.groupby("MCC")["Amount"].sum().sort_values(ascending=False)

# %%
# Import credit card data
with open("dummy-data/credit-card-data.json", "rb") as file:
    credit_card_json = json.load(file)

# %%
# Import user info
with open("dummy-data/user-info.json", "rb") as file:
    user_info = json.load(file)

# %% [markdown]
# ## Connect to OpenAI API

# %%
client = OpenAI()

pprint(client.models.list().data)
# Out:
# [Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'),
#  Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'),
#  Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'),
#  Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'),
#  Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'),
#  Model(id='babbage-002', created=1692634615, object='model', owned_by='system'),
#  Model(id='davinci-002', created=1692634301, object='model', owned_by='system'),
#  Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini', created=1721172741, object='model', owned_by='system'),
#  Model(id='tts-1', created=1681940951, object='model', owned_by='openai-internal'),
#  Model(id='gpt-3.5-turbo-16k', created=1683758102, object='model', owned_by='openai-internal'),
#  Model(id='gpt-4o-mini-2024-07-18', created=1721172717, object='model', owned_by='system'),
#  Model(id='tts-1-1106', created=1699053241, object='model', owned_by='system'),
#  Model(id='chatgpt-4o-latest', created=1723515131, object='model', owned_by='system'),
#  Model(id='gpt-4-turbo-2024-04-09', created=1712601677, object='model', owned_by='system'),
#  Model(id='gpt-4', created=1687882411, object='model', owned_by='openai'),
#  Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'),
#  Model(id='gpt-4o-realtime-preview-2024-10-01', created=1727131766, object='model', owned_by='system'),
#  Model(id='gpt-4o-realtime-preview', created=1727659998, object='model', owned_by='system'),
#  Model(id='gpt-4-turbo-preview', created=1706037777, object='model', owned_by='system'),
#  Model(id='gpt-4-1106-preview', created=1698957206, object='model', owned_by='system'),
#  Model(id='text-embedding-ada-002', created=1671217299, object='model', owned_by='openai-internal'),
#  Model(id='gpt-4-turbo', created=1712361441, object='model', owned_by='system'),
#  Model(id='text-embedding-3-small', created=1705948997, object='model', owned_by='system'),
#  Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'),
#  Model(id='gpt-4o-2024-08-06', created=1722814719, object='model', owned_by='system'),
#  Model(id='gpt-4o', created=1715367049, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'),
#  Model(id='gpt-4o-audio-preview', created=1727460443, object='model', owned_by='system'),
#  Model(id='gpt-4o-audio-preview-2024-10-01', created=1727389042, object='model', owned_by='system'),
#  Model(id='gpt-4-0613', created=1686588896, object='model', owned_by='openai'),
#  Model(id='gpt-4-0125-preview', created=1706037612, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-instruct-0914', created=1694122472, object='model', owned_by='system'),
#  Model(id='gpt-4o-2024-05-13', created=1715368132, object='model', owned_by='system')]

# %% [markdown]
# ### Let's try feeding both JSONs directly to the model

# %% [markdown]
# ### Quick demo

# %%
llm = ChatOpenAI(model="chatgpt-4o-latest")
output_parser = StrOutputParser()

# %%
rec_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a world-class expert in credit cards and you specialize in making credit card recommendations."),
    (
        "user", """
        Here is the user's financial information:
        ```json
        {user_info}
        ```
        
        Here is the user's transaction history:
        ```json
        {transactions}
        ```
        
        Here is our database of credit card information:
        ```json
        {credit_cards}
        ```
        
        Please recommend up to 4 credit cards that maximizes the savings/value across all categories. Assume the user will use all the cards you recommend, so they cannot be redundant. Ensure that you only recommend cards that the user meets the minimum credit score requirement for. 
        
        Format your answer as follows:
        1. Think through the problem step-by-step. Talk about possible factors to consider when choosing a credit card as a customer
        2. Taking all these factors into account, explain your reasoning step-by-step, which ultimately leads to your recommendations. Ensure to explain your reasoning for why you ranked some cards higher/lower than others.
        3. Rank your recommendations in ascending order by most recommended to least recommended. Output your recommendations in a list along with their value proposition like this:
        
        <answer>
        1. <card name>: <reasoning>
        2. <card name>: <reasoning>
        ...
        </answer>
        """)
])

# %%
rec_chain = rec_prompt | llm | output_parser

# %%
tx_grouped = tx_df.groupby("MCC")["Amount"].sum().sort_values(ascending=False)

# income = 100000

output = rec_chain.invoke({
    "transactions": tx_grouped,
    # "income": income,
    "credit_cards": credit_card_json,
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 5
#       1 tx_grouped = tx_df.groupby("MCC")["Amount"].sum().sort_values(ascending=False)
#       3 # income = 100000
# ----> 5 output = rec_chain.invoke({
#       6     "transactions": tx_grouped,
#       7     # "income": income,
#       8     "credit_cards": credit_card_json,
#       9 })
#
# File /opt/miniconda3/envs/c1/lib/python3.10/site-packages/langchain_core/runnables/base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020 context.run(_set_config_context, config)
#    3021 if i == 0:
# -> 3022     input = context.run(step.invoke, input, config, **kwargs)
#    3023 else:
#    3024     input = context.run(step.invoke, input, config)
#
# File /opt/miniconda3/envs/c1/lib/python3.10/site-packages/langchain_core/prompts/base.py:208, in BasePromptTemplate.invoke(self, input, config, **kwargs)
#     206 if self.tags:
#     207     config["tags"] = config["tags"] + self.tags
# --> 208 return self._call_with_config(
#     209     self._format_prompt_with_error_handling,
#     210     input,
#     211     config,
#     212     run_type="prompt",
#     213     serialized=self._serialized,
#     214 )
#
# File /opt/miniconda3/envs/c1/lib/python3.10/site-packages/langchain_core/runnables/base.py:1927, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1923     context = copy_context()
#    1924     context.run(_set_config_context, child_config)
#    1925     output = cast(
#    1926         Output,
# -> 1927         context.run(
#    1928             call_func_with_variable_args,  # type: ignore[arg-type]
#    1929             func,  # type: ignore[arg-type]
#    1930             input,  # type: ignore[arg-type]
#    1931             config,
#    1932             run_manager,
#    1933             **kwargs,
#    1934         ),
#    1935     )
#    1936 except BaseException as e:
#    1937     run_manager.on_chain_error(e)
#
# File /opt/miniconda3/envs/c1/lib/python3.10/site-packages/langchain_core/runnables/config.py:396, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     394 if run_manager is not None and accepts_run_manager(func):
#     395     kwargs["run_manager"] = run_manager
# --> 396 return func(input, **kwargs)
#
# File /opt/miniconda3/envs/c1/lib/python3.10/site-packages/langchain_core/prompts/base.py:182, in BasePromptTemplate._format_prompt_with_error_handling(self, inner_input)
#     181 def _format_prompt_with_error_handling(self, inner_input: dict) -> PromptValue:
# --> 182     _inner_input = self._validate_input(inner_input)
#     183     return self.format_prompt(**_inner_input)
#
# File /opt/miniconda3/envs/c1/lib/python3.10/site-packages/langchain_core/prompts/base.py:176, in BasePromptTemplate._validate_input(self, inner_input)
#     170     example_key = missing.pop()
#     171     msg += (
#     172         f"\nNote: if you intended {{{example_key}}} to be part of the string"
#     173         " and not a variable, please escape it with double curly braces like: "
#     174         f"'{{{{{example_key}}}}}'."
#     175     )
# --> 176     raise KeyError(
#     177         create_message(message=msg, error_code=ErrorCode.INVALID_PROMPT_INPUT)
#     178     )
#     179 return inner_input
#
# KeyError: "Input to ChatPromptTemplate is missing variables {'user_info'}.  Expected: ['credit_cards', 'transactions', 'user_info'] Received: ['transactions', 'credit_cards']\nNote: if you intended {user_info} to be part of the string and not a variable, please escape it with double curly braces like: '{{user_info}}'.\nFor troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/INVALID_PROMPT_INPUT"

# %%
tx_grouped
# Out:
# MCC
# onlineDining     $9.92$6.51$4.73$8.40$8.55$5.76$7.10$6.44$6.56$...
# dining           $76.07$80.18$12.76$92.30$76.37$80.65$80.05$87....
# other            $57.10$29.34$65.50$160.00$1.13$53.09$51.98$82....
# gas              $53.91$110.37$62.06$-99.00$99.00$145.50$153.36...
# transit          $36.82$21.10$100.34$31.68$31.40$89.12$29.38$81...
# rentalCar        $331.00$150.59$-331.00$167.05$380.00$-380.00$2...
# entertainment    $22.56$29.33$29.95$227.90$32.23$29.35$32.56$28...
# hotel            $211.00$149.45$-211.00$255.00$-255.00$147.41$2...
# streaming        $144.90$210.96$185.66$188.40$192.46$179.71$222...
# grocery          $134.09$38.48$120.34$93.84$123.50$61.72$117.05...
# retail           $128.95$104.71$86.19$45.30$147.45$56.42$36.73$...
# travel           $100.00$-100.00$164.52$393.00$-393.00$161.78$4...
# Name: Amount, dtype: object

# %%
import re
from rich.console import Console
from rich.markdown import Markdown

sections = re.split(r"###", output)

console = Console()

for section in sections:
    if section.strip():
        markdown_content = Markdown(f"### {section.strip()}")
        console.print(markdown_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2 from rich.console import Console
#       3 from rich.markdown import Markdown
# ----> 5 sections = re.split(r"###", output)
#       7 console = Console()
#       9 for section in sections:
#
# NameError: name 'output' is not defined

# %% [markdown]
# ## Use OpenAI's structured outputs

# %%
sys_prompt = """You are a world-class credit card advisor with deep expertise in personal finance, rewards optimization, and credit card benefits. Your role is to provide personalized credit card recommendations that maximize value while considering:
- Credit score requirements and approval odds
- Annual fees vs. potential rewards value
- Complementary benefits across multiple cards
- User's spending patterns and lifestyle
- Sign-up bonuses and welcome offers
- Credit issuer application rules (like Chase 5/24)
- Long-term value proposition beyond first year

Maintain a balanced perspective between optimizing rewards and responsible credit management. Be transparent about annual fees and potential drawbacks of recommended cards.
"""

rec_prompt = """Here is the user's financial information:
    ```json
    {user_info}
    ```
    
    Here is the user's transaction history:
    ```json
    {transactions}
    ```
    
    Here is our database of credit card information:
    ```json
    {credit_cards}
    ```
    
    Please recommend up to 4 credit cards that maximize the savings/value across all categories. Assume the user will use all the cards you recommend, so they cannot be redundant. Ensure that you only recommend cards that the user meets the minimum credit score requirement for.
    
    Follow this reasoning process to generate your response:
    1. **Step-by-Step Reasoning**: Begin by analyzing the user’s financial profile and spending patterns, considering factors like lifestyle, spending habits, credit score, and long-term card value. Mention key factors that influence credit card selection.
    2. **Rationale for Rankings**: Discuss the logic behind why certain cards are ranked higher or lower based on the user's needs, approval odds, potential value, and card benefits.

    Format your answer using the following pydantic models:

    ```python
    class UserInfo(BaseModel):
        global_reasoning: str  # An overview of the factors considered for all recommendations
        recommendations: list[CreditCardRec]  # A list of credit card recommendations

    class CreditCardRec(BaseModel):
        rec_reasoning: str  # Explanation for recommending this specific card
        card_name: str  # Name of the credit card being recommended
    ```

    ### Output Format
    - `UserInfo.global_reasoning`: A paragraph summarizing key factors considered across all cards.
    - `UserInfo.recommendations`: A list of `CreditCardRec` objects, each containing:
        - `rec_reasoning`: Step-by-step reasoning for why this specific card was chosen.
        - `card_name`: Name of the credit card.
    
    Please use this structured format in your response.
    """

# %%
from pydantic import BaseModel

class CreditCardRec(BaseModel):
    rec_reasoning: str
    card_name: str
    
class UserInfo(BaseModel):
    global_reasoning: str
    recommendations: list[CreditCardRec]


completion = client.beta.chat.completions.parse(
    model="gpt-4o-2024-08-06",
    messages=[
        {
            "role": "system",
            "content": sys_prompt
        },
        {
            "role": "user",
            "content": rec_prompt.format(user_info=user_info, transactions=tx_grouped, credit_cards=credit_card_json)
        },
    ],
    response_format=UserInfo,
)

# %%
rec_json = completion.choices[0].message.parsed.model_dump()

# %%
for rec in rec_json["recommendations"]:
    card_name = rec["card_name"]
    rec["card_info"] = credit_card_json[card_name]

# %%
rec_json
# Out:
# {'global_reasoning': 'The primary goal in selecting credit cards for this user was to maximize rewards based on their substantial spending patterns and high credit score. The user spends heavily on groceries and retail, with significant expenses in other categories like gas, dining, and travel. With an income of $100,000 and a willingness to pay up to $800 annually in fees, premium cards offering high category-based rewards and substantial benefits are suitable. Given the excellent credit score of 800, the user should qualify for almost any card. The combination of receiving high rewards rates and sizable sign-up bonuses while balancing annual fees and additional benefits like travel credits and insurance protections shaped the selection.',
#  'recommendations': [{'rec_reasoning': "The American Express Gold Card is an optimal choice due to its high rewards rates of 4x on both dining and grocery purchases, aligning perfectly with the user's top spending categories: grocery and dining. The card also offers flexible points redemption and additional dining credits worth up to $120 annually, significantly offsetting the $325 annual fee. The initial bonus of 80,000 points further enhances the value for heavy grocery and dining expenses, which are the user's main expenditures.",
#    'card_name': 'American Express Gold Card',
#    'card_info': {'cardName': 'American Express Gold Card',
#     'cardType': 'Credit Card',
#     'issuer': 'American Express',
#     'annualFee': 325,
#     'APR': '20.49% - 28.49%',
#     'rewards': {'pointsPerDollar': {'dining': 4,
#       'grocery': 4,
#       'travel': 3,
#       'hotel': 2,
#       'other': 1},
#      'signUpBonus': {'points': 80000,
#       'minimumSpend': 6000,
#       'timeFrameMonths': 6}},
#     'benefits': ['Up to $120 dining credit per year',
#      'Uber Cash of up to $120 each year',
#      'Flexible redemption on points',
#      "$84 Dunkin' Credit",
#      '$100 Resy Credit'],
#     'creditCardScoreMin': 670,
#     'creditCardScoreMax': 850,
#     'linkToApply': 'https://www.americanexpress.com/us/credit-cards/card/gold-card/',
#     'countryOfOrigin': 'USA'}},
#   {'rec_reasoning': "The Blue Cash Preferred Card from AmEx offers 6% cash back on groceries and streaming, 3% on gas, and travel, matching multiple high-spending categories for the user. Given the user's high grocery expenditure, this card's benefits far outweigh its $95 annual fee. The sign-up bonus of $250 after spending $3,000 in six months adds to the card's value proposition, making it a perfect fit for covering the user's priorities at exceptional rewards rates.",
#    'card_name': 'Blue Cash Preferred Card from AmEx',
#    'card_info': {'cardName': 'Blue Cash Preferred Card from AmEx',
#     'cardType': 'Credit Card',
#     'issuer': 'American Express',
#     'annualFee': 95,
#     'APR': '18.74% - 29.74%',
#     'rewards': {'pointsPerDollar': {'other': 1,
#       'grocery': 6,
#       'streaming': 6,
#       'gas': 3,
#       'travel': 3},
#      'signUpBonus': {'cash': 250, 'minimumSpend': 3000, 'timeFrameMonths': 6}},
#     'benefits': ['Purchase protection',
#      'No foreign transaction fees',
#      '$250 statement credit after spending $3,000 in first 6 months',
#      '$84 Disney Bundle Credit',
#      'Global Assist® Hotline',
#      'Events with Amex',
#      'Car Rental Loss and Damage Insurance'],
#     'creditCardScoreMin': 690,
#     'creditCardScoreMax': 850,
#     'linkToApply': 'https://card.americanexpress.com/d/blue-cash-preferred-credit-card/?utm_mcid=&utm_source=google&utm_medium=cpc&utm_term=%2Bbcprsvp&utm_cmpid=18507429010&utm_adgid=142588111672&utm_tgtid=kwd-1816175834781&utm_mt=p&utm_adid=714799789621&utm_dvc=c&utm_ntwk=g&utm_adpos=&utm_plcmnt=&utm_locphysid=9027902&utm_locintid=&utm_feeditemid=&utm_devicemdl=&utm_plcmnttgt=&utm_programname=brandcps&utm_cmp=BCP&utm_sl=&gclid=Cj0KCQiArby5BhCDARIsAIJvjIT_rSxoVMYd6luzw0CYgr69ZPF8fz_6uMCFYxR9j0wqYyyXwqEyM7QaApngEALw_wcB',
#     'countryOfOrigin': 'USA'}},
#   {'rec_reasoning': "The Chase Sapphire Reserve, with its strong travel benefits and 10x points on dining and travel (after using the $300 annual travel credit), fits the user's high travel and dining expenses perfectly. Given the user's willingness to pay high annual fees (up to $800) and the substantial benefits that cover global access, insurance, and transfer partners, this card provides a long-term value return beyond just rewards. The $550 annual fee is justified by the extensive benefits, including travel insurance and airport lounge access.",
#    'card_name': 'Chase Sapphire Reserve',
#    'card_info': {'cardName': 'Chase Sapphire Reserve',
#     'cardType': 'Credit Card',
#     'issuer': 'Chase',
#     'annualFee': 550,
#     'APR': '21.99% - 28.99%',
#     'rewards': {'pointsPerDollar': {'travel': 5,
#       'dining': 10,
#       'hotel': 10,
#       'rentalCar': 10,
#       'other': 10},
#      'signUpBonus': {'points': 60000,
#       'minimumSpend': 4000,
#       'timeFrameMonths': 3}},
#     'benefits': ['$300 annual travel credit',
#      '$1,000 in additional partnership benefit value',
#      'Airport lounge access',
#      'Travel insurance',
#      'Bonus points for certain purchases',
#      'Global Entry or TSA PreCheck® or NEXUS Fee Credit',
#      'No foreign transaction fees'],
#     'creditCardScoreMin': 720,
#     'creditCardScoreMax': 850,
#     'linkToApply': 'https://creditcards.chase.com/rewards-credit-cards/sapphire/reserve',
#     'countryOfOrigin': 'USA'}},
#   {'rec_reasoning': "The Capital One Venture Rewards Credit Card allows for 2x miles on all other purchases, with 5x on travel directly booked through Capital One, which adds value to the user's varied spending. The no foreign transaction fees and travel-focused benefits like Global Entry or TSA PreCheck credits complement the substantial gas, dining, and travel spend. The card's $95 annual fee is manageable, and the 75,000 miles welcome offer after spending $4,000 in the first three months provides a solid boost to initial rewards value.",
#    'card_name': 'Capital One Venture Rewards Credit Card',
#    'card_info': {'cardName': 'Capital One Venture Rewards Credit Card',
#     'cardType': 'Credit Card',
#     'issuer': 'Capital One',
#     'annualFee': 95,
#     'APR': '19.99% - 29.74%',
#     'rewards': {'pointsPerDollar': {'other': 2,
#       'travel': 5,
#       'hotel': 5,
#       'rentalCar': 5,
#       'vacationRental': 5},
#      'signUpBonus': {'miles': 75000,
#       'minimumSpend': 4000,
#       'timeFrameMonths': 3}},
#     'benefits': ['No foreign transaction fees',
#      'Travel accident insurance',
#      'Auto rental coverage',
#      'Credit of up to $120 for the application fee for Global Entry or TSA Precheck when you pay with the card.',
#      'Extended warranty on eligible items.'],
#     'creditCardScoreMin': 700,
#     'creditCardScoreMax': 850,
#     'linkToApply': 'https://www.capitalone.com/credit-cards/venture/',
#     'countryOfOrigin': 'USA'}}]}

# %% [markdown]
# ## Calculate the user's savings using the recommended cards

# %%
tx_grouped
# Out:
# MCC
# grocery          497988.79
# retail           487190.51
# other            253515.79
# gas              185779.92
# dining            90767.45
# travel            49914.39
# streaming         24677.00
# hotel             21504.94
# entertainment      7487.52
# onlineDining       1621.93
# transit            1563.74
# rentalCar           979.71
# Name: Amount, dtype: float64

# %%
credit_card_json
# Out:
# {'Chase Sapphire Preferred Card': {'cardName': 'Chase Sapphire Preferred Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 95,
#   'APR': '20.99% - 27.99%',
#   'rewards': {'pointsPerDollar': {'travel': 5,
#     'dining': 3,
#     'onlineGrocery': 3,
#     'streaming': 3,
#     'other': 1},
#    'signUpBonus': {'points': 60000,
#     'minimumSpend': 4000,
#     'timeFrameMonths': 3}},
#   'benefits': ['$300 in travel credits in the first year',
#    'Primary rental car insurance',
#    'No foreign transaction fees',
#    '$150 in additional partnership benefit value',
#    '1:1 point transfer with partners',
#    'Travel and purchase coverage'],
#   'creditCardScoreMin': 650,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/rewards-credit-cards/sapphire/preferred',
#   'countryOfOrigin': 'USA'},
#  'Capital One Venture Rewards Credit Card': {'cardName': 'Capital One Venture Rewards Credit Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Capital One',
#   'annualFee': 95,
#   'APR': '19.99% - 29.74%',
#   'rewards': {'pointsPerDollar': {'other': 2,
#     'travel': 5,
#     'hotel': 5,
#     'rentalCar': 5,
#     'vacationRental': 5},
#    'signUpBonus': {'miles': 75000,
#     'minimumSpend': 4000,
#     'timeFrameMonths': 3}},
#   'benefits': ['No foreign transaction fees',
#    'Travel accident insurance',
#    'Auto rental coverage',
#    'Credit of up to $120 for the application fee for Global Entry or TSA Precheck when you pay with the card.',
#    'Extended warranty on eligible items.'],
#   'creditCardScoreMin': 700,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.capitalone.com/credit-cards/venture/',
#   'countryOfOrigin': 'USA'},
#  'AmEx Platinum Card': {'cardName': 'AmEx Platinum Card',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express',
#   'annualFee': 695,
#   'APR': '20.49% - 28.49%',
#   'rewards': {'pointsPerDollar': {'other': 1, 'travel': 5, 'hotel': 5},
#    'signUpBonus': {'points': 80000,
#     'minimumSpend': 8000,
#     'timeFrameMonths': 6}},
#   'benefits': ['American Express Global Lounge Collection',
#    '$200 airline fee credit',
#    '$200 Uber Cash',
#    '$240 digital entertainment credit',
#    '$200 hotel credit annually',
#    'Various travel protections',
#    '$199 CLEAR® Plus Credit',
#    'Fine Hotels + Resorts and The Hotel Collection',
#    'Global Dining Access by Resy',
#    'Premium Car Rental Protection',
#    'Walmart+ Monthly Membership Credit',
#    'Cell Phone Protection',
#    '$100 Shop Saks With Platinum'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://card.americanexpress.com/d/platinum-card/?utm_mcid=&utm_source=google&utm_medium=cpc&utm_term=%2Bamerican%20%2Bexpress%20%2Bplatinum&utm_cmpid=18507428845&utm_adgid=142828790300&utm_tgtid=kwd-383918391531&utm_mt=p&utm_adid=718242918426&utm_dvc=c&utm_ntwk=g&utm_adpos=&utm_plcmnt=&utm_locphysid=9027902&utm_locintid=&utm_feeditemid=&utm_devicemdl=&utm_plcmnttgt=&utm_programname=brandcps&utm_cmp=Platinum&utm_sl=&gclid=Cj0KCQiArby5BhCDARIsAIJvjIS6r8sv-CNjT_GqafNb7LHp49KiZa7JGF8FgV3A0WAfjc-RT5exYYgaAnfYEALw_wcB',
#   'countryOfOrigin': 'USA'},
#  'Discover it Cash Back': {'cardName': 'Discover it Cash Back',
#   'cardType': 'Credit Card',
#   'issuer': 'Discover',
#   'annualFee': 0,
#   'APR': '18.74% - 27.74%',
#   'rewards': {'pointsPerDollar': {'other': 1, 'categories': 1500},
#    'signUpBonus': {'points': 30000,
#     'minimumSpend': None,
#     'timeFrameMonths': 12}},
#   'benefits': ['No annual fee',
#    '0% intro APR for 15 months on purchases and balance transfers',
#    'Cashback does not expire',
#    'Extra rewards opportunities available through rotations'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.discover.com/products/it-card.html?sc=GJVC&iq_id=r43700078743878789&cmpgnid=ps-dca-google-brand-cashback&source=PSGOOGLE&gad_source=1&gclid=Cj0KCQiArby5BhCDARIsAIJvjITv1P8hMvqFbpxYqr0kyBS6cYXUXBlmCdmtRFCXAXh-vDvn4O-0XFwaAgXBEALw_wcB&gclsrc=aw.ds',
#   'countryOfOrigin': 'USA'},
#  'Wells Fargo Active Cash Card': {'cardName': 'Wells Fargo Active Cash Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Wells Fargo',
#   'annualFee': 0,
#   'APR': '19.74% - 29.74%',
#   'rewards': {'pointsPerDollar': {'other': 2},
#    'signUpBonus': {'points': 20000,
#     'minimumSpend': 500,
#     'timeFrameMonths': 3}},
#   'benefits': ['Cellphone protection up to $600 against damage or theft',
#    'Access to Visa Signature perks',
#    'Auto Rental Collision Damage Waiver',
#    'Travel and Emergency Assistance Services',
#    'Roadside Dispatch',
#    'Emergency Cash Disbursement and Card Replacement',
#    'Zero Liability protection'],
#   'creditCardScoreMin': 670,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.wellsfargo.com/cards/active-cash-credit-card/?FPID=0126D7I6F40000&product_code=CC&subproduct_code=AC&sub_channel=SEM&vendor_code=G&Placement_ID=71700000085077219_43700076272756699&gclid=Cj0KCQiArby5BhCDARIsAIJvjITVN5F4sXZHiHTQXkz4eicf5XEI3fEGM0ktY3S7TjKOMC9X_iZbv6kaAl0_EALw_wcB&gclsrc=aw.ds',
#   'countryOfOrigin': 'USA'},
#  'Citi Double Cash Card': {'cardName': 'Citi Double Cash Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Citibank',
#   'annualFee': 0,
#   'APR': '18.74% - 28.74%',
#   'rewards': {'pointsPerDollar': {'other': 2},
#    'signUpBonus': {'cash': 200, 'minimumSpend': 1500, 'timeFrameMonths': 6}},
#   'benefits': ['0% intro APR on balance transfers for 18 months',
#    'Purchase protection',
#    'Theft protection',
#    'Lost wallet service',
#    'Concierge services'],
#   'creditCardScoreMin': 630,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.citi.com/usc/LPACA/Citi/Cards/DoubleCash/ps_A/index.html?cmp=knc|acquire|2006|CARDS|Google|BR&targetid=kwd-99517658725&gclid=Cj0KCQiArby5BhCDARIsAIJvjISas_kwsIFtGZ0ptPXxJMseQqXom3_ScfsNzLIxsQ5ezay84QFDz_kaAqt3EALw_wcB&gclsrc=aw.ds&ProspectID=PwAblNXLlS2SHJ2YJGxHSZC6c8AuHEDU',
#   'countryOfOrigin': 'USA'},
#  'Blue Cash Preferred Card from AmEx': {'cardName': 'Blue Cash Preferred Card from AmEx',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express',
#   'annualFee': 95,
#   'APR': '18.74% - 29.74%',
#   'rewards': {'pointsPerDollar': {'other': 1,
#     'grocery': 6,
#     'streaming': 6,
#     'gas': 3,
#     'travel': 3},
#    'signUpBonus': {'cash': 250, 'minimumSpend': 3000, 'timeFrameMonths': 6}},
#   'benefits': ['Purchase protection',
#    'No foreign transaction fees',
#    '$250 statement credit after spending $3,000 in first 6 months',
#    '$84 Disney Bundle Credit',
#    'Global Assist® Hotline',
#    'Events with Amex',
#    'Car Rental Loss and Damage Insurance'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://card.americanexpress.com/d/blue-cash-preferred-credit-card/?utm_mcid=&utm_source=google&utm_medium=cpc&utm_term=%2Bbcprsvp&utm_cmpid=18507429010&utm_adgid=142588111672&utm_tgtid=kwd-1816175834781&utm_mt=p&utm_adid=714799789621&utm_dvc=c&utm_ntwk=g&utm_adpos=&utm_plcmnt=&utm_locphysid=9027902&utm_locintid=&utm_feeditemid=&utm_devicemdl=&utm_plcmnttgt=&utm_programname=brandcps&utm_cmp=BCP&utm_sl=&gclid=Cj0KCQiArby5BhCDARIsAIJvjIT_rSxoVMYd6luzw0CYgr69ZPF8fz_6uMCFYxR9j0wqYyyXwqEyM7QaApngEALw_wcB',
#   'countryOfOrigin': 'USA'},
#  'Citi Custom Cash Card': {'cardName': 'Citi Custom Cash Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Citi',
#   'annualFee': 0,
#   'APR': '18.74% - 28.74%',
#   'rewards': {'pointsPerDollar': {'other': 1, 'categories': 500},
#    'signUpBonus': {'cash': 200, 'minimumSpend': 1500, 'timeFrameMonths': 6}},
#   'benefits': ['Free FICO score access',
#    'Access to World Elite Mastercard benefits'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.citi.com/usc/LPACA/Citi/Cards/CustomCash/ps/index.html?cmp=knc|acquire|2006|CARDS|Google|BR&gclid=Cj0KCQiArby5BhCDARIsAIJvjIQRV27mKswLliSfkEE94QW-k6rG-CMSdT_cb7098AlYetDNFnOzQowaAlvyEALw_wcB&gclsrc=aw.ds&ProspectID=PP9mrkfNdrx3Z9DNSpKft8EbbYNIcv8D',
#   'countryOfOrigin': 'USA'},
#  'Chase Freedom Unlimited': {'cardName': 'Chase Freedom Unlimited',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 0,
#   'APR': '19.99% - 28.74%',
#   'rewards': {'pointsPerDollar': {'other': 1.5,
#     'dining': 3,
#     'onlineDining': 3,
#     'travel': 5},
#    'signUpBonus': {'cash': 200, 'minimumSpend': 500, 'timeFrameMonths': 3}},
#   'benefits': ['Purchase protection for 120 days against damage or theft, up to $500 per claim',
#    'Travel insurance including Trip Cancellation and Interruption coverage',
#    'Trip Cancellation/Interruption Insurance',
#    'Auto Rental Collision Damage Waiver'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/cash-back-credit-cards/freedom/unlimited',
#   'countryOfOrigin': 'USA'},
#  'Wells Fargo Reflect Card': {'cardName': 'Wells Fargo Reflect Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Wells Fargo',
#   'annualFee': 0,
#   'APR': '17.74% - 29.49%',
#   'rewards': {},
#   'benefits': ['0% intro APR for 21 months',
#    'Cell phone protection',
#    'Zero Liability protection'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.wellsfargo.com/reflect-visa-credit-card/?sub_channel=SEO&vendor_code=G',
#   'countryOfOrigin': 'USA'},
#  'Chase Freedom Flex': {'cardName': 'Chase Freedom Flex',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 0,
#   'APR': '19.99% - 28.74%',
#   'rewards': {'pointsPerDollar': {'other': 1,
#     'dining': 3,
#     'drugstore': 3,
#     'travel': 5,
#     'categories': 1500},
#    'signUpBonus': {'cash': 200, 'minimumSpend': 500, 'timeFrameMonths': 3}},
#   'benefits': ['Welcome bonus of $200 after spending $500 in the first 3 months',
#    '0% intro APR for 15 months on purchases and balance transfers',
#    'No foreign transaction fees',
#    'Service and Protection'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/cash-back-credit-cards/freedom/flex',
#   'countryOfOrigin': 'USA'},
#  'Capital One Savor Cash Rewards Card': {'cardName': 'Capital One Savor Cash Rewards Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Capital One',
#   'annualFee': 0,
#   'APR': '19.74% - 29.74%',
#   'rewards': {'pointsPerDollar': {'other': 1,
#     'entertainment': 8,
#     'dining': 3,
#     'hotel': 5,
#     'rentalCar': 5,
#     'travel': 5},
#    'signUpBonus': {'cash': 250, 'minimumSpend': 500, 'timeFrameMonths': 3}},
#   'benefits': ['No foreign transaction fees',
#    '0% intro APR for 15 months on purchases and balance transfers',
#    'Lifetime reward expiry',
#    'Travel Accident Insurance'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.capitalone.com/credit-cards/savor/',
#   'countryOfOrigin': 'USA'},
#  'U.S. Bank Cash Plus Visa Signature Card': {'cardName': 'U.S. Bank Cash Plus Visa Signature Card',
#   'cardType': 'Credit Card',
#   'issuer': 'U.S. Bank',
#   'annualFee': 0,
#   'APR': '18.74% - 28.99%',
#   'rewards': {'pointsPerDollar': {'other': 1,
#     'categories': 2000,
#     'dining': 2,
#     'travel': 5},
#    'signUpBonus': {'cash': 200, 'minimumSpend': 1000, 'timeFrameMonths': 3}},
#   'benefits': ['0% intro APR on purchases and balance transfers for the first 15 billing cycles'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.usbank.com/credit-cards/cash-plus-visa-signature-credit-card.html',
#   'countryOfOrigin': 'USA'},
#  'American Express Gold Card': {'cardName': 'American Express Gold Card',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express',
#   'annualFee': 325,
#   'APR': '20.49% - 28.49%',
#   'rewards': {'pointsPerDollar': {'dining': 4,
#     'grocery': 4,
#     'travel': 3,
#     'hotel': 2,
#     'other': 1},
#    'signUpBonus': {'points': 80000,
#     'minimumSpend': 6000,
#     'timeFrameMonths': 6}},
#   'benefits': ['Up to $120 dining credit per year',
#    'Uber Cash of up to $120 each year',
#    'Flexible redemption on points',
#    "$84 Dunkin' Credit",
#    '$100 Resy Credit'],
#   'creditCardScoreMin': 670,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.americanexpress.com/us/credit-cards/card/gold-card/',
#   'countryOfOrigin': 'USA'},
#  'Citi Simplicity Card': {'cardName': 'Citi Simplicity Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Citi',
#   'annualFee': 0,
#   'APR': '18.74% - 29.49%',
#   'rewards': {},
#   'benefits': ['No late fees',
#    'No penalty rate',
#    '0% intro APR for 21 months on balance transfers',
#    '0% intro APR for 12 months on purchases'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.citi.com/usc/LPACA/Citi/Cards/Simplicity/ps/index.html?cmp=knc|acquire|2006|CARDS|Google|BR&targetid=kwd-1249299615&gclid=Cj0KCQiArby5BhCDARIsAIJvjIQVw4pgnlMLH29Gc7bwDAt24w3hiIzs7qsvheGRRFR4nDQpZeJjJK0aAtk_EALw_wcB&gclsrc=aw.ds&ProspectID=PXiDb0StDAmpZgoggmxgebYFyhr1K6Tw',
#   'countryOfOrigin': 'USA'},
#  'Hilton Honors American Express Card': {'cardName': 'Hilton Honors American Express Card',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express',
#   'annualFee': 0,
#   'APR': '20.49% - 29.49%',
#   'rewards': {'pointsPerDollar': {'hotel': 7,
#     'dining': 5,
#     'gas': 5,
#     'other': 3},
#    'signUpBonus': {'points': 100000,
#     'minimumSpend': 2000,
#     'timeFrameMonths': 6}},
#   'benefits': ['Complimentary Hilton Honors Gold status',
#    'No foreign transaction fees',
#    'Car Rental Loss and Damage Insurance'],
#   'creditCardScoreMin': 670,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.americanexpress.com/us/credit-cards/card/hilton-honors/',
#   'countryOfOrigin': 'USA'},
#  'Citi Strata Premier Card': {'cardName': 'Citi Strata Premier Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Citi',
#   'annualFee': 95,
#   'APR': '20.74% - 28.74%',
#   'rewards': {'pointsPerDollar': {'hotel': 10,
#     'rentalCar': 10,
#     'travel': 3,
#     'dining': 3,
#     'grocery': 3,
#     'gas': 3,
#     'other': 1},
#    'signUpBonus': {'points': 75000,
#     'minimumSpend': 4000,
#     'timeFrameMonths': 3}},
#   'benefits': ['Travel insurance protections',
#    'No foreign transaction fees',
#    '$100 hotel credit on stays of $500 or more'],
#   'creditCardScoreMin': 670,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.citi.com/credit-cards/citi-strata-premier-credit-card',
#   'countryOfOrigin': 'USA'},
#  'U.S. Bank Visa Platinum Card': {'cardName': 'U.S. Bank Visa Platinum Card',
#   'cardType': 'Credit Card',
#   'issuer': 'U.S. Bank',
#   'annualFee': 0,
#   'APR': '17.99% - 28.99%',
#   'rewards': {},
#   'benefits': ['Cell phone protection',
#    'No foreign transaction fees',
#    'Auto pay & due date choice',
#    'ID Navigator Powered by NortonLifeLock'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.usbank.com/credit-cards/visa-platinum-credit-card.html',
#   'countryOfOrigin': 'USA'},
#  'Bank of America Travel Rewards Credit Card': {'cardName': 'Bank of America Travel Rewards Credit Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Bank of America',
#   'annualFee': 0,
#   'APR': '18.74% - 28.74%',
#   'rewards': {'pointsPerDollar': {'other': 1.5},
#    'signUpBonus': {'points': 25000,
#     'minimumSpend': 1000,
#     'timeFrameMonths': 3}},
#   'benefits': ['No foreign transaction fees'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.bankofamerica.com/credit-cards/products/travel-rewards-credit-card/',
#   'countryOfOrigin': 'USA'},
#  'Discover it Student Cash Back': {'cardName': 'Discover it Student Cash Back',
#   'cardType': 'Credit Card',
#   'issuer': 'Discover',
#   'annualFee': 0,
#   'APR': '17.74% - 26.74%',
#   'rewards': {'pointsPerDollar': {'other': 1, 'dining': 5},
#    'signUpBonus': {'points': 25000,
#     'minimumSpend': None,
#     'timeFrameMonths': 12}},
#   'benefits': ['First-year cashback match',
#    'No annual fee',
#    'No foreign transaction fees',
#    'Free FICO score access',
#    'Short introductory APR period on purchases'],
#   'creditCardScoreMin': 630,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.discover.com/products/student-it.html?sc=RJQS&iq_id=r43700079725617932&cmpgnid=ps-dca-google-student-brand-cashback&source=PSGOOGLE&gclid=Cj0KCQiArby5BhCDARIsAIJvjIQoKhyqPS7_97xkzuywqCFwoK6re5lmFqUMl0OHQ4wEArpODJnw5VoaAgJfEALw_wcB&gclsrc=aw.ds',
#   'countryOfOrigin': 'USA'},
#  'Delta SkyMiles Gold American Express Card': {'cardName': 'Delta SkyMiles Gold American Express Card',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express National Bank',
#   'annualFee': 150,
#   'APR': '20.24% - 29.24%',
#   'rewards': {'pointsPerDollar': {'dining': 2,
#     'onlineDining': 2,
#     'grocery': 2,
#     'travel': 2,
#     'other': 1},
#    'signUpBonus': {'miles': 50000,
#     'minimumSpend': 2000,
#     'timeFrameMonths': 6}},
#   'benefits': ['$200 Delta Flight Credit after spending $10,000 in a calendar year',
#    'Free first checked bag',
#    'Priority boarding',
#    '20% rebate on in-flight purchases'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.americanexpress.com/us/credit-cards/card/delta-skymiles-gold-american-express-card/',
#   'countryOfOrigin': 'USA'},
#  'American Express Green Card': {'cardName': 'American Express Green Card',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express',
#   'annualFee': 150,
#   'APR': '20.49% - 28.49%',
#   'rewards': {'pointsPerDollar': {'travel': 3,
#     'rentalCar': 3,
#     'hotel': 3,
#     'transit': 3,
#     'dining': 3,
#     'other': 1},
#    'signUpBonus': {'points': 40000,
#     'minimumSpend': 3000,
#     'timeFrameMonths': 6}},
#   'benefits': ['Trip delay insurance',
#    '$199 CLEAR® Plus Credit',
#    'Secondary auto rental coverage',
#    'No Foreign Transaction Fees'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.americanexpress.com/us/credit-cards/card/green/',
#   'countryOfOrigin': 'USA'},
#  'Chase Sapphire Reserve': {'cardName': 'Chase Sapphire Reserve',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 550,
#   'APR': '21.99% - 28.99%',
#   'rewards': {'pointsPerDollar': {'travel': 5,
#     'dining': 10,
#     'hotel': 10,
#     'rentalCar': 10,
#     'other': 10},
#    'signUpBonus': {'points': 60000,
#     'minimumSpend': 4000,
#     'timeFrameMonths': 3}},
#   'benefits': ['$300 annual travel credit',
#    '$1,000 in additional partnership benefit value',
#    'Airport lounge access',
#    'Travel insurance',
#    'Bonus points for certain purchases',
#    'Global Entry or TSA PreCheck® or NEXUS Fee Credit',
#    'No foreign transaction fees'],
#   'creditCardScoreMin': 720,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/rewards-credit-cards/sapphire/reserve',
#   'countryOfOrigin': 'USA'},
#  'Alaska Airlines Visa Signature Credit Card': {'cardName': 'Alaska Airlines Visa Signature Credit Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Bank of America',
#   'annualFee': 95,
#   'APR': '20.74% - 28.74%',
#   'rewards': {'pointsPerDollar': {'travel': 3,
#     'gas': 2,
#     'streaming': 2,
#     'other': 1},
#    'signUpBonus': {'miles': 60000,
#     'minimumSpend': 3000,
#     'timeFrameMonths': 3}},
#   'benefits': ['Annual Companion Fare (starting at $122) if $6,000 spent in previous card year',
#    'Free checked bag for cardholder and companions',
#    'Priority boarding',
#    '20% rebate on in-flight purchases'],
#   'creditCardScoreMin': 670,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.bankofamerica.com/credit-cards/products/alaska-airlines-credit-card/',
#   'countryOfOrigin': 'USA'},
#  'Marriott Bonvoy Business Credit Card': {'cardName': 'Marriott Bonvoy Business Credit Card',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express',
#   'annualFee': 125,
#   'APR': '20.24% - 29.24%',
#   'rewards': {'pointsPerDollar': {'hotel': 6,
#     'dining': 4,
#     'gas': 4,
#     'other': 2},
#    'signUpBonus': {'points': 150000,
#     'minimumSpend': 6000,
#     'timeFrameMonths': 6}},
#   'benefits': ['No foreign transaction fees',
#    'Complimentary Marriott Bonvoy Gold Elite Status',
#    'Marriott Bonvoy® Room Rate Discount',
#    'Earn & Redeem Free Nights'],
#   'creditCardScoreMin': 670,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.americanexpress.com/us/credit-cards/business/business-credit-cards/amex-marriott-bonvoy-business-credit-card/',
#   'countryOfOrigin': 'USA'},
#  'United Explorer Card': {'cardName': 'United Explorer Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 95,
#   'APR': '21.49% - 28.49%',
#   'rewards': {'pointsPerDollar': {'travel': 7,
#     'hotel': 4,
#     'dining': 2,
#     'allOtherPurchases': 1},
#    'signUpBonus': {'miles': 50000,
#     'minimumSpend': 3000,
#     'timeFrameMonths': 3}},
#   'benefits': ['Free first checked bag',
#    'Priority boarding',
#    'Up to $100 Global Entry or TSA PreCheck fee credit',
#    '25% back on eligible in-flight purchases',
#    '2 United Club one-time passes per year'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/travel-credit-cards/united/united-explorer',
#   'countryOfOrigin': 'USA'},
#  'Amazon Prime Rewards Visa Signature Card': {'cardName': 'Amazon Prime Rewards Visa Signature Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 0,
#   'APR': '19.99% - 28.74%',
#   'rewards': {'pointsPerDollar': {'other': 1,
#     'dining': 2,
#     'amazon': 5,
#     'gas': 2},
#    'signUpBonus': {'miles': 20000, 'minimumSpend': 0, 'timeFrameMonths': 0}},
#   'benefits': ['No annual fee',
#    'High rewards rate on Amazon purchases',
#    'Instant Amazon gift card upon approval',
#    'Prime Card Bonus',
#    'No foreign transaction fees'],
#   'creditCardScoreMin': 670,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/cash-back-credit-cards/amazon-prime-rewards',
#   'countryOfOrigin': 'USA'},
#  'IHG Rewards Club Premier Credit Card': {'cardName': 'IHG Rewards Club Premier Credit Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 99,
#   'APR': '20.99% - 27.99%',
#   'rewards': {'pointsPerDollar': {'hotel': 26,
#     'travel': 5,
#     'dining': 5,
#     'gas': 5,
#     'other': 3},
#    'signUpBonus': {'points': 140000,
#     'minimumSpend': 3000,
#     'timeFrameMonths': 3}},
#   'benefits': ['Free night certificate annually',
#    'Automatic Platinum Elite status',
#    'Earn $100 & 10,000 bonus points',
#    'Global Entry, TSA PreCheck or NEXUS fee reimbursement',
#    'Other travel benefits'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/travel-credit-cards/ihg-rewards-club/premier',
#   'countryOfOrigin': 'USA'},
#  'British Airways Visa Signature Card': {'cardName': 'British Airways Visa Signature Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Chase',
#   'annualFee': 95,
#   'APR': '20.99% - 27.99%',
#   'rewards': {'pointsPerDollar': {'travel': 3, 'hotel': 2, 'other': 1},
#    'signUpBonus': {'avios': 85000,
#     'minimumSpend': 5000,
#     'timeFrameMonths': 3}},
#   'benefits': ['10% discount on British Airways flights from the U.S.',
#    'No foreign transaction fees',
#    'Up to $600 Reward Flight Statement Credits',
#    'Purchase Protection'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://creditcards.chase.com/travel-credit-cards/avios/british-airways',
#   'countryOfOrigin': 'USA'},
#  'American Express Blue Card': {'cardName': 'American Express Blue Card',
#   'cardType': 'Credit Card',
#   'issuer': 'American Express',
#   'annualFee': 0,
#   'APR': '18.49% - 29.49%',
#   'rewards': {'pointsPerDollar': {'other': 1,
#     'retail': 3,
#     'grocery': 6,
#     'gas': 3},
#    'signUpBonus': {'cash': 250, 'minimumSpend': 2000, 'timeFrameMonths': 6}},
#   'benefits': ['Access to Amex’s Pay It Plan It program',
#    'Various statement credits',
#    'Rewards programs associated with specific purchases',
#    '$84 Disney Bundle Credit',
#    '$180 Home Chef Credit',
#    'Send & Split',
#    'Events with Amex'],
#   'creditCardScoreMin': 690,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.americanexpress.com/us/credit-cards/card/blue-cash-everyday/',
#   'countryOfOrigin': 'USA'},
#  'Scotiabank Gold American Express Card': {'cardName': 'Scotiabank Gold American Express Card',
#   'cardType': 'Credit Card',
#   'issuer': 'Scotiabank',
#   'annualFee': 120,
#   'APR': '20.99% - 22.99%',
#   'rewards': {'pointsPerDollar': {'grocery': 6,
#     'dining': 5,
#     'entertainment': 5,
#     'gas': 3,
#     'streaming': 3},
#    'signUpBonus': {'points': 25000,
#     'minimumSpend': 1000,
#     'timeFrameMonths': 3}},
#   'benefits': ['No foreign transaction fees',
#    'Travel insurance',
#    'Access to exclusive American Express events',
#    'Concierge services'],
#   'creditCardScoreMin': 650,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.scotiabank.com/ca/en/personal/credit-cards/american-express/gold-card.html',
#   'countryOfOrigin': 'Canada'},
#  'BMO Air Miles Mastercard': {'cardName': 'BMO Air Miles Mastercard',
#   'cardType': 'Credit Card',
#   'issuer': 'BMO',
#   'annualFee': 0,
#   'APR': '20.99%',
#   'rewards': {'pointsPerDollar': {'gas': 4,
#     'grocery': 2,
#     'rentalCar': 3,
#     'other': 1},
#    'signUpBonus': {'points': 800, 'minimumSpend': 1000, 'timeFrameMonths': 3}},
#   'benefits': ['Purchase protection',
#    'No foreign transaction fees',
#    'Extended warranty',
#    'Discounts with specific retailers'],
#   'creditCardScoreMin': 660,
#   'creditCardScoreMax': 850,
#   'linkToApply': 'https://www.bmo.com/main/personal/credit-cards/bmo-airmiles-mastercard/',
#   'countryOfOrigin': 'Canada'}}
